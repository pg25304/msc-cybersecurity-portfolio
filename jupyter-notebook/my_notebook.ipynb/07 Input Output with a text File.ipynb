# %%
pwd # Print Working Directory to find your directory
# Out:
# 'C:\\Users\\jezabel2\\My Python Stuff'

# %%
#%% syntax, which is commonly used in certain Python environments like Jupyter Notebook to indicate cell magic commands.

#%%writefile myfile.txt
#This is line 
#this is line 
#This is line

# %%
# %load_ext storemagic #load necessary module to use cell magic command as I got above error when i start using %%writefile command
# Out:
# The storemagic extension is already loaded. To reload it, use:
#   %reload_ext storemagic

# %%
# %reload_ext storemagic

# %%
# %%writefile myfile.txt #this line must be in first cell
# This is line one
# This is line two
# This is line three
# Out:
# UsageError: unrecognized arguments: #this line must be in first cell

# %%
myfile = open('myfile.txt') #you won't get error as there is such a file on same directory of your current working jupiter notebook

# %%
myfile = open('whoops.txt') #get error; [Errno 2] No such file or directory: 'whoops.txt'
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 myfile = open('whoops.txt')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'whoops.txt'

# %%
pwd # will show your current  jupiter notebook directory
# Out:
# 'C:\\Users\\jezabel2\\My Python Stuff'

# %%
myfile.read() # method use to read and return your text file content /n= new line
# Out:
# 'This is line one\nThis is line two\nThis is line three\n'

# %%
myfile.read() # there is a cursor which read from the beginning to end of your content on text file
#now the cursor is at the end of text, so to return it to the beginning usemethod .seek(0)
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
contents = myfile.read()
#now you can see the content again, again cursor stuck at the end of text
contents #this return as a gient string
# Out:
# 'This is line one\nThis is line two\nThis is line three\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines()#each line is one string member of a list you can use for loopor 

#to call and work with a file text anywhere on your PC you should provide the path in a specific format
#C:\Users\jezabel2\Documents (path on my PC)
#C:\\Users\\jezabel2\\Documents   you should use the path like this 
# escape charcter is "\" (backslash), and it allows you to insert special characters within strings. 
#using double backslash prevent confusion for python
# Out:
# ['This is line one\n', 'This is line two\n', 'This is line three\n']

# %%
txf = open("C:\\Users\\jezabel2\\Desktop\\python.txt")# I save this file on this directory

# %%
txf.readlines()
# Out:
# ['Hello world\n',
#  'This is Payman\n',
#  'This is a challenging journey\n',
#  'which I am going to take']

# %%
txf.seek(0)
# Out:
# 0

# %%
## sometimes you want to delete but get error that the file is opened to prevent this
#you should close the file manually  txf.close().so when you finish work with a file you should close it manually
#in order to prevent this error #SO BEST PRACTICES for OPENING a file is:Using special "with" statement:
#below the first line will open a new line with indentation; Python relies on indentation to indicate code hierarchy
#and block structure.

with open('C:\\Users\\jezabel2\\Desktop\\python.txt') as new_variable:#because the text file I refer is not on the same 
    #directory of python I have to add the path as well otherwise the name of file would works
    contents = new_variable.read()#this block with indentation take new_variable as a variable of python.txt

# %%
contents
# Out:
# 'Hello world\nThis is Payman\nThis is a challenging journey\nwhich I am going to take'

# %%
#Reading, Writing, appending mode
# File Access Modes:
# 'r' - Reading mode (default): Opens file for reading only
# 'w' - Writing mode: Creates a new file or truncates existing file
# 'a' - Appending mode: Opens file for appending; creates if doesn't exist
# Additional modifiers:
# 'b' - Binary mode (e.g., 'rb', 'wb')
# 't' - Text mode (default) (e.g., 'rt', 'wt')
# '+' - Reading and writing (e.g., 'r+', 'w+')
# Out:
# UsageError: Line magic function `%%writefile` not found.

# %%
# %reload_ext storemagic

# %%
# %%writefile my_new_file.txt
# This is one
# This is two
# This is three
# Out:
# Writing my_new_file.txt

# %%
pwd
# Out:
# 'C:\\Users\\jezabel2\\My Python Stuff'

# %%
with open('my_new_file.txt',mode='r') as f:
    print(f.read())
# Out:
# This is one
# This is two
# This is three

# %%
with open('my_new_file.txt', mode = 'a') as f: #a as append add new element or line at the end of page
    f.write('This is line four')

# %%
with open('abcd.txt', mode= 'w') as f:#there is no abcd.txt file exist so python will create one
    f.write('this should be one line in a new created txt file')

# %%
# %%writefile tex.txt
# Hello world
# This is Captain Payman
# How are you?
# This could should create a text file
# Out:
# Overwriting tex.txt

# %%
# %%writefile tex.txt
# I am overwriting this text file only with one line
# Out:
# Overwriting tex.txt

# %%
with open('C:\\Users\\jezabel2\\My Python Stuff\\TEX.TXT', mode='w') as l:
    l.write("\n This is the second line \n this is third line")
