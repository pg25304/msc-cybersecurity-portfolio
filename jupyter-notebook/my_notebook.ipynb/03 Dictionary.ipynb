# %%
#my_dict = {'key1':'value1','key2':'value2'} key must be string
fruit_price = {'apple':2.00,'bannana':'1.00','cucumber':'0.5','pinapple':'3.00'}
fruit_price
# Out:
# {'apple': 2.0, 'bannana': '1.00', 'cucumber': '0.5', 'pinapple': '3.00'}

# %%
fruit_price['cucumber'] #to access a value a key should be called
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 fruit_price['cucumber']
#
# NameError: name 'fruit_price' is not defined

# %%
#dictionary is flexible with data type
d = {'key1':3, 'key2':[1,2,3],'key3':{'apple':2.0, 'another dic':'within a dictionary'}}
d['key3']
# Out:
# {'apple': 2.0, 'another dic': 'within a dictionary'}

# %%
d2 = {'key1':2.0, 'key2':['a', 'b', 'c']}#grab c and make it capital
#d2['key2'][2].upper()
d2['key2'][1].capitalize()
# Out:
# 'B'

# %%
#dictionary can be amended, add or remove element
dic3 = {'k1':100, 'k2':76, 'k3':50}
dic3['k4']=1111 #add k4 to dic
dic3
# Out:
# {'k1': 100, 'k2': 76, 'k3': 50, 'k4': 1111}

# %%
dic3['k3'] = 30#amend value of k3

# %%
dic3
# Out:
# {'k1': 100, 'k2': 76, 'k3': 30, 'k4': 1111}

# %%
dic3.keys()#.keys() return all key in dic
# Out:
# dict_keys(['k1', 'k2', 'k3', 'k4'])

# %%
dic3.values()#.values() return all values
# Out:
# dict_values([100, 76, 30, 1111])

# %%
dic3.items()#.items() return all keys :values-- ('k4', 1111) is a tuple
# Out:
# dict_items([('k1', 100), ('k2', 76), ('k3', 30), ('k4', 1111)])
