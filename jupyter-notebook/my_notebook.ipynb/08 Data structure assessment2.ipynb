# %%
# Getting a little tricker
d = {'k1':[{'nest_key':['this is deep',['hello']]}]}

#Grab hello
print(d['k1'][0]['nest_key'][1][0])
# Out:
# hello

# %%
# This will be hard and annoying! grab hello
d = {'k1':[1,2,{'k2':['this is tricky',{'tough':[1,2,['hello']]}]}]}
print(d['k1'][2]['k2'][1]['tough'][2][0])
# Out:
# hello

# %%
print("my name is {x}, and I am {y} years old".format(x="payman", y="57"))
# Out:
# my name is payman, and I am 57 years old

# %% [markdown]
# # Assistant
# The error occurs because Python is case-sensitive, and the `print()` function should be lowercase, not uppercase.
#
# Would you like me to provide the corrected code?

# %% [markdown]
# # User
# f string syntax

# %% [markdown]
# # Assistant
# If you'd like to use f-string syntax instead of the `.format()` method, here's the corrected code:

# %%
print(f"my name is {'payman'}")
# Out:
# my name is payman

# %% [markdown]
# The corrections include:
# 1. Changed `Print` to lowercase `print` (Python is case-sensitive)
# 2. Used f-string syntax (introduced in Python 3.6+) which is more readable and concise than the `.format()` method

# %%
# Formatting with f-strings (Python 3.6+)
name='payman'
age=57
pi=3.1456534
print(f"My name is {name} and I am {age} years old.")
print(f"Pi rounded to 2 decimal places: {pi:.2f}")
print(f"Right aligned: {pi:>50.2f}")
print(f"Left aligned: {pi:<20.2f}") # it does not matter if you use 10, or 30 instead of 20 because there is no space available
# Out:
# My name is payman and I am 57 years old.
# Pi rounded to 2 decimal places: 3.15
# Right aligned:                                               3.15
# Left aligned: 3.15
