# %%
mylist = [1,3,4,6] #function is a reusable block of code that defines outside of a class and you call it by name and pass in argument 
mylist.append(10)#.append() is a method all methods are function but not vise versa
mylist
# Out:
# [1, 3, 4, 6, 10]

# %%
#if you typean object and a dot "mylist." and then press Tab Python provide list of available methods and attributes
#when you chose your method but need help for syntax you can press Shift+Tab (first way) or use help() function (second way)
# i.e. you have mylist.insert but no idea about insert
help(mylist.insert)# you get documentation of object
#third method is go to the documentation site following https:www.docs.python.org
# Out:
# Help on built-in function insert:
#
# insert(index, object, /) method of builtins.list instance
#     Insert object before index.

# %%
mylist.insert(2,'Parisa')
print(mylist)
# Out:
# [1, 3, 'Parisa', 4, 6, 10]
