# %%
1==1
# Out:
# True

# %%
1!=1
# Out:
# False

# %%
10>5 and 6>2
# Out:
# True

# %%
10>5 or 3>9
# Out:
# True

# %%
not 1==1
# Out:
# False

# %%
2<=3
# Out:
# True

# %%
3>=1 and 8>=8
# Out:
# True
