# %%
#ordered, sequence data
my_list = [1,2,3,'Parisa', 2.09]
print(len(my_list))
# Out:
# 5

# %%
my_list2 = [4,5,6,'Payman', 3.09]
#Concantenation same as string
my_list + my_list2
# Out:
# [1, 2, 3, 'Parisa', 2.09, 4, 5, 6, 'Payman', 3.09]

# %%
my_list2 + my_list
# Out:
# [4, 5, 6, 'Payman', 3.09, 1, 2, 3, 'Parisa', 2.09]

# %%
my_list[3]
# Out:
# 'Parisa'

# %%
my_list[2:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 my_list[2:]
#
# NameError: name 'my_list' is not defined

# %%
#you can change an elemnt in the list on the contrary with string
my_list
# Out:
# [1, 2, 3, 'Parisa', 2.09]

# %%
my_list[0]='I changed the first element'
my_list
# Out:
# ['I changed the first element', 2, 3, 'Parisa', 2.09]

# %%
# elements can be added to the end of list
my_newlist = ['Par','Pay', 100,20.87 ,12 ,34 ]
my_newlist.append('sep')
my_newlist.append('Jigar')
my_newlist
# Out:
# ['Par', 'Pay', 100, 20.87, 12, 34, 'sep', 'Jigar']

# %%
#if you want to add in a specific position use .insert(index,value)
mylist4 = [1,2,3,4,5,6]
mylist4.insert(3,200)
mylist4
# Out:
# [1, 2, 3, 200, 4, 5, 6]

# %%
#to remove an element using .pop(index) if do not specified index by default it will remove the last element
mylist4.pop()
# Out:
# 6

# %%
mylist4.pop(3)
# Out:
# 200

# %%
mylist4
# Out:
# [1, 2, 3, 4, 5]

# %%
#A list can be reversed or sorted using reverse() and sort(), correspondingly."
mylist5 = [3,2,67,12,87,3,4]
x = mylist5.reverse() #it does return nothing, to see what it return you should assign a variable
#mylist5.sort()  it does return nothing, to see what it return you should assign a variable

# %%
type(x)   # type() use to identify the type (int, float,none,..) of data inside of a variable, 
#this prove mylist.reverse() does not return anything
# Out:
# NoneType

# %%
#to fix you should assign a variable
x = mylist5
x
# Out:
# [4, 3, 87, 12, 67, 2, 3]

# %%
mylis1=[1,2,3,4] #nested list
mylis2=[5,6,7,8]
mynested = [mylis1,mylis2]

# %%
print(mynested)
# Out:
# [[1, 2, 3, 4], [5, 6, 7, 8]]

# %%
mynested[0][1]#0 means first list and 1 means second element
# Out:
# 2

# %%
mynested[1][2]
# Out:
# 7
