# %%
#Tuple is simillar list but uses prantesis and it is immutable (unchangable)
t = (1,2,3,4,[1,2,3],'Payman')
type(t) #In Python, type() is a built-in function used to determine the type of an object
# Out:
# tuple

# %%
len(t)
# Out:
# 6

# %%
t[1]
# Out:
# 2

# %%
t[1:] #same as list
# Out:
# (2, 3, 4, [1, 2, 3], 'Payman')

# %%
t = (1,2,3,4,3,5,7)
t.count(3) # there are two built in methods. It gives how many times it happen
# Out:
# 2

# %%
t.index(2)#gives the positon of charactor
# Out:
# 1

# %%
t[2] = 'new' #onthe contrary with list, this is reason using tuple to make sure element 
#does not get re-assignment (data integrity)intentionally or accidentally
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 t[2] = 'new'
#
# TypeError: 'tuple' object does not support item assignment
