# %%
hungry = False
if hungry:
    print("I want to be fed")
else:
    print("I am not hungry")
# Out:
# I am not hungry

# %%
name = 'Parisa'

if name == "Parisa":
    print("I love you")
elif name =='Narges':
    print('Not love you')

else:
    print("she is not Parisa")
# Out:
# I love you
