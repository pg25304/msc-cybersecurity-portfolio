# %%
#sets are unordered uniques elements they cannot contain dictionary,  list, or another set myset = {1,2,3,}
myset = {1,2}
myset.add("Parysa")
myset
# Out:
# {1, 2, 'Parysa'}

# %%
myset.add([1,2,3]) #In Python, only immutable (unchangeable) objects can be added to sets because sets use hash values 
#of elements for internal operations
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 myset.add([1,2,3])
#
# TypeError: unhashable type: 'list'

# %%
myset.add({'k1':2, 'K2':34})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 myset.add({'k1':2, 'K2':34})
#
# TypeError: unhashable type: 'dict'

# %%
myset[0] =345
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 myset[0] =345
#
# TypeError: 'set' object does not support item assignment

# %%
mylist = [1,2,3,1,1,3,3,3,2,2] #when you call a list for set(), it only get unique value without ORDER
set(mylist)
# Out:
# {1, 2, 3}

# %%
set('Mississippi')
# Out:
# {'M', 'i', 'p', 's'}
