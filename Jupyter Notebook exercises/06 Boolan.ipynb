# %%
#for comparison nd logicprogramming True and False
1>2
# Out:
# False

# %%
3>1 #Make sure T and F be capital
# Out:
# True

# %%
34==34
# Out:
# True

# %%
#if you waxnt to keep a place holder for a variable and later on assign value use None
x=None
