# %%
car = 'Ford'
if car == 'Fiat':
    print('This is fiat')

elif car == 'BUick':
    print('This is Buick')
elif car == 'Ford':
    print('This is Ford')
else:
    print('this is Paykan')
# Out:
# This is Ford
